# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# Part 1: Data Loading and Basic Inspection

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Chinmayee\\Desktop'

# %%
os.chdir(r'C:\Users\Chinmayee\Desktop')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Chinmayee\\Desktop'

# %%
# 1. Load the dataset and display the first 10 rows.

# %%
df=pd.read_excel('ICICIBANK.xlsx',sheet_name='ICICIBANK')

# %%
df.head(10)
# Out:
#                        Price     Adj Close         Close          High  \
# 0                     Ticker  ICICIBANK.NS  ICICIBANK.NS  ICICIBANK.NS
# 1                       Date           NaN           NaN           NaN
# 2  2002-07-01 00:00:00+00:00     17.831417     25.127272      25.81818
# 3  2002-07-02 00:00:00+00:00      18.97975     26.745455     27.636362
# 4  2002-07-03 00:00:00+00:00     19.934542     28.090908     28.181818
# 5  2002-07-04 00:00:00+00:00     19.437794     27.390909     28.799999
# 6  2002-07-05 00:00:00+00:00     19.637785     27.672728     27.863636
# 7  2002-07-08 00:00:00+00:00     19.334568     27.245455     27.890909
# 8  2002-07-09 00:00:00+00:00     19.224901     27.090908     27.681818
# 9  2002-07-10 00:00:00+00:00     19.153938      26.99091     27.272726
#
#             Low          Open        Volume
# 0  ICICIBANK.NS  ICICIBANK.NS  ICICIBANK.NS
# 1           NaN           NaN           NaN
# 2      24.81818      25.41818       2047540
# ...

# %%
#2. Identify the column names of the dataset.

df.columns
# Out:
# Index(['Price', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %%
#3. Check the number of rows and columns in the dataset.

df.shape
# Out:
# (5557, 7)

# %%
#4. Display the data types of all columns.

df.dtypes
# Out:
# Price        object
# Adj Close    object
# Close        object
# High         object
# Low          object
# Open         object
# Volume       object
# dtype: object

# %%
#5. Check for missing values in the dataset.
#6. Count the total number of missing values for each column.

df.isnull().sum()
# Out:
# Price        0
# Adj Close    1
# Close        1
# High         1
# Low          1
# Open         1
# Volume       1
# dtype: int64

# %%
#7. Display summary statistics of all numeric columns.

df.describe()
# Out:
#                             Price    Adj Close        Close         High  \
# count                        5557  5556.000000  5556.000000  5556.000000
# unique                       5557  5280.000000  5089.000000  4664.000000
# top     2024-11-13 00:00:00+00:00    19.347469    27.263636    26.363636
# freq                            1     4.000000     4.000000     7.000000
#
#                 Low  Open  Volume
# count   5556.000000  5556    5556
# unique  4731.000000  4230    5525
# top       25.454544   200       0
# freq       6.000000    13      31

# %%
#8. Rename columns to make them more readable (e.g., replace spaces with underscores).

df.columns = df.columns.str.replace(' ', '_')
df.columns
# Out:
# Index(['Price', 'Adj_Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %%
#9. Check if there are any duplicate rows.

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#10. Drop rows where all elements are NaN.

df=df.dropna().reset_index(drop=True)
df
# Out:
#                           Price     Adj_Close         Close          High  \
# 0                        Ticker  ICICIBANK.NS  ICICIBANK.NS  ICICIBANK.NS
# 1     2002-07-01 00:00:00+00:00     17.831417     25.127272      25.81818
# 2     2002-07-02 00:00:00+00:00      18.97975     26.745455     27.636362
# 3     2002-07-03 00:00:00+00:00     19.934542     28.090908     28.181818
# 4     2002-07-04 00:00:00+00:00     19.437794     27.390909     28.799999
# ...                         ...           ...           ...           ...
# 5551  2024-11-07 00:00:00+00:00   1278.699951   1278.699951   1302.800049
# 5552  2024-11-08 00:00:00+00:00   1258.849976   1258.849976          1275
# 5553  2024-11-11 00:00:00+00:00   1269.300049   1269.300049   1275.900024
# 5554  2024-11-12 00:00:00+00:00   1270.599976   1270.599976          1295
# 5555  2024-11-13 00:00:00+00:00   1253.699951   1253.699951       1276.25
#
#                Low          Open        Volume
# ...

# %%
#11. Remove rows that are not part of the main data (e.g., header rows duplicated in the data).

df=df.drop([0],axis=0)

# %%
df.columns=['Date', 'Adj_Close', 'Close', 'High', 'Low', 'Open', 'Volume']
df
# Out:
#                            Date    Adj_Close        Close         High  \
# 1     2002-07-01 00:00:00+00:00    17.831417    25.127272     25.81818
# 2     2002-07-02 00:00:00+00:00     18.97975    26.745455    27.636362
# 3     2002-07-03 00:00:00+00:00    19.934542    28.090908    28.181818
# 4     2002-07-04 00:00:00+00:00    19.437794    27.390909    28.799999
# 5     2002-07-05 00:00:00+00:00    19.637785    27.672728    27.863636
# ...                         ...          ...          ...          ...
# 5551  2024-11-07 00:00:00+00:00  1278.699951  1278.699951  1302.800049
# 5552  2024-11-08 00:00:00+00:00  1258.849976  1258.849976         1275
# 5553  2024-11-11 00:00:00+00:00  1269.300049  1269.300049  1275.900024
# 5554  2024-11-12 00:00:00+00:00  1270.599976  1270.599976         1295
# 5555  2024-11-13 00:00:00+00:00  1253.699951  1253.699951      1276.25
#
#               Low         Open    Volume
# 1        24.81818     25.41818   2047540
# ...

# %%
#12. Convert the Date column into a proper datetime object.

df['Date']=pd.to_datetime(df['Date']).dt.tz_localize(None).dt.strftime('%Y-%m-%d')
df
# Out:
#             Date    Adj_Close        Close         High          Low  \
# 1     2002-07-01    17.831417    25.127272     25.81818     24.81818
# 2     2002-07-02     18.97975    26.745455    27.636362    25.236362
# 3     2002-07-03    19.934542    28.090908    28.181818    26.645454
# 4     2002-07-04    19.437794    27.390909    28.799999    27.036364
# 5     2002-07-05    19.637785    27.672728    27.863636    26.945454
# ...          ...          ...          ...          ...          ...
# 5551  2024-11-07  1278.699951  1278.699951  1302.800049      1275.25
# 5552  2024-11-08  1258.849976  1258.849976         1275  1252.699951
# 5553  2024-11-11  1269.300049  1269.300049  1275.900024  1246.650024
# 5554  2024-11-12  1270.599976  1270.599976         1295       1264.5
# 5555  2024-11-13  1253.699951  1253.699951      1276.25         1250
#
#              Open    Volume
# 1        25.41818   2047540
# 2       25.454544   5546354
# 3       26.727272   5745267
# ...

# %%
pd.to_datetime(df['Date'])
# Out:
# 1      2002-07-01
# 2      2002-07-02
# 3      2002-07-03
# 4      2002-07-04
# 5      2002-07-05
#           ...
# 5551   2024-11-07
# 5552   2024-11-08
# 5553   2024-11-11
# 5554   2024-11-12
# 5555   2024-11-13
# Name: Date, Length: 5555, dtype: datetime64[ns]

# %%
#13. Extract the year, month, and day from the Date column as new columns.

import pandas as pd

# Example: Assume df has a 'Date' column
# Convert the 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# Extract year, month, and day
df['Year'] = df['Date'].dt.year
df['Month'] =df['Date'].dt.month
df['Day'] =df['Date'].dt.day

# %%
df
# Out:
#            Date    Adj_Close        Close         High          Low  \
# 1    2002-07-01    17.831417    25.127272     25.81818     24.81818
# 2    2002-07-02     18.97975    26.745455    27.636362    25.236362
# 3    2002-07-03    19.934542    28.090908    28.181818    26.645454
# 4    2002-07-04    19.437794    27.390909    28.799999    27.036364
# 5    2002-07-05    19.637785    27.672728    27.863636    26.945454
# ...         ...          ...          ...          ...          ...
# 5551 2024-11-07  1278.699951  1278.699951  1302.800049      1275.25
# 5552 2024-11-08  1258.849976  1258.849976         1275  1252.699951
# 5553 2024-11-11  1269.300049  1269.300049  1275.900024  1246.650024
# 5554 2024-11-12  1270.599976  1270.599976         1295       1264.5
# 5555 2024-11-13  1253.699951  1253.699951      1276.25         1250
#
#              Open    Volume  Year  Month  Day
# 1        25.41818   2047540  2002      7    1
# 2       25.454544   5546354  2002      7    2
# ...

# %%
#19. Create a new column prev close,daily return , SMA_50, SMA_200

df['Prev Close'] = df['Close'].shift(1)

# %%
df['Daily Return'] = ((df['Close'] - df['Prev Close']) / df['Prev Close']) * 100
df
# Out:
#            Date    Adj_Close        Close         High          Low  \
# 1    2002-07-01    17.831417    25.127272     25.81818     24.81818
# 2    2002-07-02     18.97975    26.745455    27.636362    25.236362
# 3    2002-07-03    19.934542    28.090908    28.181818    26.645454
# 4    2002-07-04    19.437794    27.390909    28.799999    27.036364
# 5    2002-07-05    19.637785    27.672728    27.863636    26.945454
# ...         ...          ...          ...          ...          ...
# 5551 2024-11-07  1278.699951  1278.699951  1302.800049      1275.25
# 5552 2024-11-08  1258.849976  1258.849976         1275  1252.699951
# 5553 2024-11-11  1269.300049  1269.300049  1275.900024  1246.650024
# 5554 2024-11-12  1270.599976  1270.599976         1295       1264.5
# 5555 2024-11-13  1253.699951  1253.699951      1276.25         1250
#
#              Open    Volume  Year  Month  Day   Prev Close Daily Return
# 1        25.41818   2047540  2002      7    1         None          NaN
# ...

# %%
df['SMA_50'] = df['Close'].rolling(window=50, min_periods=1).mean()
df
# Out:
#            Date    Adj_Close        Close         High          Low  \
# 1    2002-07-01    17.831417    25.127272     25.81818     24.81818
# 2    2002-07-02     18.97975    26.745455    27.636362    25.236362
# 3    2002-07-03    19.934542    28.090908    28.181818    26.645454
# 4    2002-07-04    19.437794    27.390909    28.799999    27.036364
# 5    2002-07-05    19.637785    27.672728    27.863636    26.945454
# ...         ...          ...          ...          ...          ...
# 5551 2024-11-07  1278.699951  1278.699951  1302.800049      1275.25
# 5552 2024-11-08  1258.849976  1258.849976         1275  1252.699951
# 5553 2024-11-11  1269.300049  1269.300049  1275.900024  1246.650024
# 5554 2024-11-12  1270.599976  1270.599976         1295       1264.5
# 5555 2024-11-13  1253.699951  1253.699951      1276.25         1250
#
#              Open    Volume  Year  Month  Day   Prev Close Daily Return  \
# 1        25.41818   2047540  2002      7    1         None          NaN
# ...

# %%
df['SMA_200'] = df['Close'].rolling(window=200, min_periods=1).mean()
df
# Out:
#            Date    Adj_Close        Close         High          Low  \
# 1    2002-07-01    17.831417    25.127272     25.81818     24.81818
# 2    2002-07-02     18.97975    26.745455    27.636362    25.236362
# 3    2002-07-03    19.934542    28.090908    28.181818    26.645454
# 4    2002-07-04    19.437794    27.390909    28.799999    27.036364
# 5    2002-07-05    19.637785    27.672728    27.863636    26.945454
# ...         ...          ...          ...          ...          ...
# 5551 2024-11-07  1278.699951  1278.699951  1302.800049      1275.25
# 5552 2024-11-08  1258.849976  1258.849976         1275  1252.699951
# 5553 2024-11-11  1269.300049  1269.300049  1275.900024  1246.650024
# 5554 2024-11-12  1270.599976  1270.599976         1295       1264.5
# 5555 2024-11-13  1253.699951  1253.699951      1276.25         1250
#
#              Open    Volume  Year  Month  Day   Prev Close Daily Return  \
# 1        25.41818   2047540  2002      7    1         None          NaN
# ...

# %%
df=df.dropna().reset_index(drop=True)
df
# Out:
#            Date    Adj_Close        Close         High          Low  \
# 0    2002-07-02     18.97975    26.745455    27.636362    25.236362
# 1    2002-07-03    19.934542    28.090908    28.181818    26.645454
# 2    2002-07-04    19.437794    27.390909    28.799999    27.036364
# 3    2002-07-05    19.637785    27.672728    27.863636    26.945454
# 4    2002-07-08    19.334568    27.245455    27.890909    27.172728
# ...         ...          ...          ...          ...          ...
# 5549 2024-11-07  1278.699951  1278.699951  1302.800049      1275.25
# 5550 2024-11-08  1258.849976  1258.849976         1275  1252.699951
# 5551 2024-11-11  1269.300049  1269.300049  1275.900024  1246.650024
# 5552 2024-11-12  1270.599976  1270.599976         1295       1264.5
# 5553 2024-11-13  1253.699951  1253.699951      1276.25         1250
#
#              Open    Volume  Year  Month  Day   Prev Close Daily Return  \
# 0       25.454544   5546354  2002      7    2    25.127272     6.439948
# ...

# %%
#20. Filter out rows with Volume values below a certain threshold (e.g., 10,000).

df[df['Volume'] >= 10000]
# Out:
#            Date    Adj_Close        Close         High          Low  \
# 0    2002-07-02     18.97975    26.745455    27.636362    25.236362
# 1    2002-07-03    19.934542    28.090908    28.181818    26.645454
# 2    2002-07-04    19.437794    27.390909    28.799999    27.036364
# 3    2002-07-05    19.637785    27.672728    27.863636    26.945454
# 4    2002-07-08    19.334568    27.245455    27.890909    27.172728
# ...         ...          ...          ...          ...          ...
# 5549 2024-11-07  1278.699951  1278.699951  1302.800049      1275.25
# 5550 2024-11-08  1258.849976  1258.849976         1275  1252.699951
# 5551 2024-11-11  1269.300049  1269.300049  1275.900024  1246.650024
# 5552 2024-11-12  1270.599976  1270.599976         1295       1264.5
# 5553 2024-11-13  1253.699951  1253.699951      1276.25         1250
#
#              Open    Volume  Year  Month  Day   Prev Close Daily Return  \
# 0       25.454544   5546354  2002      7    2    25.127272     6.439948
# ...

# %% [markdown]
# Part 3: Data Exploration

# %%
#21. Find the total number of unique dates in the dataset.

df.nunique()
# Out:
# Date            5554
# Adj_Close       5278
# Close           5087
# High            4663
# Low             4730
# Open            4228
# Volume          5523
# Year              23
# Month             12
# Day               31
# Prev Close      5087
# Daily Return    5506
# SMA_50          5550
# SMA_200         5554
# dtype: int64

# %%
#22. Identify the date with the highest Volume.

vol=df['Volume'].max()
vol1 = np.where(df['Volume'] == vol)[0][0]

# %%
max_volume= df.loc[vol1, 'Date']
max_volume
# Out:
# Timestamp('2019-11-26 00:00:00')

# %%
#23. Find the average Adj Close value for each year.

df['Year']=df['Date'].dt.year
df['Year']
# Out:
# 0       2002
# 1       2002
# 2       2002
# 3       2002
# 4       2002
#         ...
# 5549    2024
# 5550    2024
# 5551    2024
# 5552    2024
# 5553    2024
# Name: Year, Length: 5554, dtype: int32

# %%
avg=df.groupby('Year')['Adj_Close'].mean()
avg
# Out:
# Year
# 2002     17.746811
# 2003     23.046809
# 2004      39.80051
# 2005     63.486479
# 2006     90.783883
# 2007    141.421333
# 2008    109.018956
# 2009      98.59024
# 2010    148.096279
# 2011      147.6719
# 2012    146.521539
# 2013    168.215943
# 2014    228.629394
# 2015    253.358594
# 2016    208.074924
# 2017     265.61117
# 2018    300.332857
# 2019    405.734316
# 2020    399.729321
# 2021    640.900223
# 2022    784.644869
# 2023    910.449082
# 2024    1143.78273
# Name: Adj_Close, dtype: object

# %%
#24. Determine the median High value across all rows.

df['High'].median()
# Out:
# np.float64(208.5545425415035)

# %%
#25. Find the correlation between Adj Close, High, and Low.

df[['Adj_Close', 'High', 'Low']].corr()
# Out:
#            Adj_Close      High       Low
# Adj_Close   1.000000  0.999517  0.999547
# High        0.999517  1.000000  0.999848
# Low         0.999547  0.999848  1.000000

# %%
df[['Adj_Close', 'High', 'Low']].dtypes
# Out:
# Adj_Close    object
# High         object
# Low          object
# dtype: object

# %%
#26. List the top 5 dates with the highest Close values.

df[df['Close'] == df['Close'].max()].head()
# Out:
#            Date    Adj_Close        Close         High          Low  Open  \
# 5516 2024-09-20  1338.449951  1338.449951  1362.349976  1291.550049  1295
#
#         Volume  Year  Month  Day Prev Close Daily Return       SMA_50  \
# 5516  73257767  2024      9   20       1292     3.595197  1219.527991
#
#           SMA_200
# 5516  1111.262497

# %%
#27. Count how many times the Volume exceeded 1 million.

(df['Volume'] > 1000000).sum()
# Out:
# np.int64(5489)

# %%
#27. Count how many times the Volume exceeded 1 million.

(df['Volume'] > 1000000).sum()
# Out:
# np.int64(5489)

# %%
#28. Find the maximum and minimum values of Open for each year.

df.groupby('Year')['Open'].agg(['max','min'])
# Out:
#               max         min
# Year
# 2002    28.181818   20.272726
# 2003    56.363636   21.945454
# 2004    69.054543   38.463634
# 2005   109.890907   61.636364
# 2006   164.218185   84.372726
# 2007   241.790909  146.118179
# 2008   263.636353   54.772728
# 2009        172.5   47.945454
# 2010   231.454544  129.454544
# 2011   209.818176  120.363632
# 2012   210.018188  125.481819
# 2013   223.636368  142.472733
# 2014   330.727264  172.699997
# 2015   348.136353   224.77272
# 2016   262.909088  167.545456
# 2017        324.0  229.181824
# 2018   370.100006      260.25
# 2019   549.599976  339.100006
# 2020        549.0       284.0
# 2021   830.099976  514.599976
# 2022        956.0  643.299988
# 2023  1043.650024       800.0
# 2024       1333.0  973.950012

# %%
#29. Calculate the daily price difference (High - Low) and create a new column for it.

df['Daily_Price'] = df['High'] - df['Low']
df['Daily_Price']
# Out:
# 0             2.4
# 1        1.536364
# 2        1.763636
# 3        0.918182
# 4        0.718182
#           ...
# 5549    27.550049
# 5550    22.300049
# 5551        29.25
# 5552         30.5
# 5553        26.25
# Name: Daily_Price, Length: 5554, dtype: object

# %%
#30. Identify the date with the largest daily price difference.

df[df['Daily_Price'] == df['Daily_Price'].max()]['Date'].iloc[0]
# Out:
# Timestamp('2024-06-04 00:00:00')

# %% [markdown]
# Part 4: Grouping and Aggregation

# %%
#31. Group the data by year and calculate the total Volume for each year.

df.groupby('Year')['Volume'].sum()
# Out:
# Year
# 2002      330839013
# 2003     1771777535
# 2004     1961486160
# 2005     1314181664
# 2006     1668177256
# 2007     2921115557
# 2008    10376396386
# 2009    13307398968
# 2010     5430688137
# 2011     5730833336
# 2012     5339393341
# 2013     5087911348
# 2014     3846819683
# 2015     3416330211
# 2016     4855845106
# 2017     4261044697
# 2018     5056296999
# 2019     4913455694
# 2020     8935979308
# 2021     4344554519
# 2022     3222123115
# 2023     4036182581
# 2024     3389278559
# Name: Volume, dtype: object

# %%
#32. Find the average Close value for each month across all years.

df['Close'].mean()
# Out:
# np.float64(312.1571357158349)

# %%
#33. Determine the year with the highest average Adj Close.

l=df.groupby('Year')['Adj_Close'].mean()
l
# Out:
# Year
# 2002     17.746811
# 2003     23.046809
# 2004      39.80051
# 2005     63.486479
# 2006     90.783883
# 2007    141.421333
# 2008    109.018956
# 2009      98.59024
# 2010    148.096279
# 2011      147.6719
# 2012    146.521539
# 2013    168.215943
# 2014    228.629394
# 2015    253.358594
# 2016    208.074924
# 2017     265.61117
# 2018    300.332857
# 2019    405.734316
# 2020    399.729321
# 2021    640.900223
# 2022    784.644869
# 2023    910.449082
# 2024    1143.78273
# Name: Adj_Close, dtype: object

# %%
df['Year'].max()
# Out:
# np.int32(2024)

# %%
#34. Group the data by Date and calculate the sum of Volume for each.

df.groupby('Date')['Volume'].sum()
# Out:
# Date
# 2002-07-02     5546354
# 2002-07-03     5745267
# 2002-07-04     3896601
# 2002-07-05     3261038
# 2002-07-08     2092667
#                 ...
# 2024-11-07     9909035
# 2024-11-08    11195808
# 2024-11-11     8387780
# 2024-11-12    13486168
# 2024-11-13    12259953
# Name: Volume, Length: 5554, dtype: object

# %%
df.head()
# Out:
#         Date  Adj_Close      Close       High        Low       Open   Volume  \
# 0 2002-07-02   18.97975  26.745455  27.636362  25.236362  25.454544  5546354
# 1 2002-07-03  19.934542  28.090908  28.181818  26.645454  26.727272  5745267
# 2 2002-07-04  19.437794  27.390909  28.799999  27.036364  28.181818  3896601
# 3 2002-07-05  19.637785  27.672728  27.863636  26.945454  27.090908  3261038
# 4 2002-07-08  19.334568  27.245455  27.890909  27.172728  27.881819  2092667
#
#    Year  Month  Day Prev Close Daily Return     SMA_50    SMA_200 Daily_Price
# 0  2002      7    2  25.127272     6.439948  25.936363  25.936363         2.4
# 1  2002      7    3  26.745455     5.030587  26.654545  26.654545    1.536364
# 2  2002      7    4  28.090908    -2.491905  26.838636  26.838636    1.763636
# 3  2002      7    5  27.390909     1.028876  27.005454  27.005454    0.918182
# 4  2002      7    8  27.672728    -1.544021  27.045454  27.045454    0.718182

# %%
#35. Identify months where the average Close exceeded 10.

df.loc[np.where(df.groupby('Month')['Close'].mean()>10)]
# Out:
#          Date  Adj_Close      Close       High        Low       Open   Volume  \
# 0  2002-07-02   18.97975  26.745455  27.636362  25.236362  25.454544  5546354
# 1  2002-07-03  19.934542  28.090908  28.181818  26.645454  26.727272  5745267
# 2  2002-07-04  19.437794  27.390909  28.799999  27.036364  28.181818  3896601
# 3  2002-07-05  19.637785  27.672728  27.863636  26.945454  27.090908  3261038
# 4  2002-07-08  19.334568  27.245455  27.890909  27.172728  27.881819  2092667
# 5  2002-07-09  19.224901  27.090908  27.681818  26.927273       27.4  1026800
# 6  2002-07-10  19.153938   26.99091  27.272726   26.90909  27.236362  1513611
# 7  2002-07-11  19.012003  26.790909  27.081818  26.545454  27.081818  1454750
# 8  2002-07-12  19.012003  26.790909   27.40909  26.672728  27.272726   475040
# 9  2002-07-15  18.715244  26.372726   26.90909  26.181818  26.890909   535634
# 10 2002-07-16  18.553963  26.145454  26.363636       25.9  26.181818  1400542
# ...

# %% [markdown]
# Part 5: Filtering and Sorting

# %%
#36. Filter rows where the High is greater than 10.

df.loc[np.where(df['High']>10)]
# Out:
#            Date    Adj_Close        Close         High          Low  \
# 0    2002-07-02     18.97975    26.745455    27.636362    25.236362
# 1    2002-07-03    19.934542    28.090908    28.181818    26.645454
# 2    2002-07-04    19.437794    27.390909    28.799999    27.036364
# 3    2002-07-05    19.637785    27.672728    27.863636    26.945454
# 4    2002-07-08    19.334568    27.245455    27.890909    27.172728
# ...         ...          ...          ...          ...          ...
# 5549 2024-11-07  1278.699951  1278.699951  1302.800049      1275.25
# 5550 2024-11-08  1258.849976  1258.849976         1275  1252.699951
# 5551 2024-11-11  1269.300049  1269.300049  1275.900024  1246.650024
# 5552 2024-11-12  1270.599976  1270.599976         1295       1264.5
# 5553 2024-11-13  1253.699951  1253.699951      1276.25         1250
#
#              Open    Volume  Year  Month  Day   Prev Close Daily Return  \
# 0       25.454544   5546354  2002      7    2    25.127272     6.439948
# ...

# %%
#37. Sort the dataset by Date in ascending order.

df.sort_values(by='Date',ascending=True,inplace=True)
df
# Out:
#            Date    Adj_Close        Close         High          Low  \
# 0    2002-07-02     18.97975    26.745455    27.636362    25.236362
# 1    2002-07-03    19.934542    28.090908    28.181818    26.645454
# 2    2002-07-04    19.437794    27.390909    28.799999    27.036364
# 3    2002-07-05    19.637785    27.672728    27.863636    26.945454
# 4    2002-07-08    19.334568    27.245455    27.890909    27.172728
# ...         ...          ...          ...          ...          ...
# 5549 2024-11-07  1278.699951  1278.699951  1302.800049      1275.25
# 5550 2024-11-08  1258.849976  1258.849976         1275  1252.699951
# 5551 2024-11-11  1269.300049  1269.300049  1275.900024  1246.650024
# 5552 2024-11-12  1270.599976  1270.599976         1295       1264.5
# 5553 2024-11-13  1253.699951  1253.699951      1276.25         1250
#
#              Open    Volume  Year  Month  Day   Prev Close Daily Return  \
# 0       25.454544   5546354  2002      7    2    25.127272     6.439948
# ...

# %%
#38. Find all rows where Volume is between 500,000 and 1,000,000.

r=df[(df['Volume'] >=500000) & (df['Volume'] <= 1000000)]
r
# Out:
#           Date  Adj_Close      Close       High        Low       Open  Volume  \
# 9   2002-07-15  18.715244  26.372726   26.90909  26.181818  26.890909  535634
# 23  2002-08-02  18.147528  25.572727  26.363636  23.654545  26.363636  987239
# 27  2002-08-08  17.515303  24.681818         25  24.572727  24.927273  881501
# 30  2002-08-13  17.328213   24.41818  24.727272         24  24.545454  710748
# 31  2002-08-14  17.070156  24.054544  24.727272   23.91818  24.472727  573578
# 35  2002-08-20  17.418535  24.545454  25.090908       24.5  25.081818  533890
# 42  2002-08-29   17.92173  25.254545  25.454544  25.027271   25.31818  680449
# 44  2002-09-02  18.353977  25.863636  26.454544  25.681818  26.181818  559938
# 47  2002-09-05  18.083019  25.481817  25.636362  25.181818  25.618181  611853
# 51  2002-09-11  18.579767  26.181818  26.436363   25.90909  25.972729  997804
# 53  2002-09-13  18.489452  26.054544  26.472727   23.90909   23.90909  699270
# ...

# %%
#39. Retrieve rows where the Close price is higher than the Open price.

df.iloc[np.where(df['Close'] > df['Open'])]
# Out:
#            Date    Adj_Close        Close         High          Low  \
# 0    2002-07-02     18.97975    26.745455    27.636362    25.236362
# 1    2002-07-03    19.934542    28.090908    28.181818    26.645454
# 3    2002-07-05    19.637785    27.672728    27.863636    26.945454
# 11   2002-07-17    18.682987    26.327272     26.49091           26
# 13   2002-07-19    18.779755    26.463636    27.272726    25.454544
# ...         ...          ...          ...          ...          ...
# 5542 2024-10-29  1331.849976  1331.849976  1335.349976      1299.25
# 5545 2024-11-01  1291.800049  1291.800049  1296.199951      1286.25
# 5547 2024-11-05  1296.699951  1296.699951  1301.300049  1263.099976
# 5548 2024-11-06  1302.349976  1302.349976         1315  1292.699951
# 5551 2024-11-11  1269.300049  1269.300049  1275.900024  1246.650024
#
#              Open    Volume  Year  Month  Day   Prev Close Daily Return  \
# 0       25.454544   5546354  2002      7    2    25.127272     6.439948
# ...

# %%
#40. Filter out rows where Low is less than 5.

df.iloc[np.where(df['Low']<5)]
# Out:
# Empty DataFrame
# Columns: [Date, Adj_Close, Close, High, Low, Open, Volume, Year, Month, Day, Prev Close, Daily Return, SMA_50, SMA_200, Daily_Price]
# Index: []

# %% [markdown]
#  Part 6: Visualization Practice

# %%
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
import scipy
from scipy import stats
from scipy.stats import norm, t
from scipy.stats import binom
import seaborn as sns
import pylab
from pylab import legend,plot,show,title,xlabel,ylabel
from numpy import random

# %%
#41. Plot the trend of Adj Close values over time.

plt.plot(df['Date'], df['Adj_Close'], label='Adj_Close', color='brown')
plt.title('Trading Adj_Close Over Time')
plt.xlabel('Date')
plt.ylabel('Adj_Close')
plt.grid()
plt.show()

# %%
#42. Visualize the distribution of Volume using a histogram.

plt.bar(df['Date'],df['Volume'], color='rosybrown')
plt.title('Distribution of Volume')
plt.xlabel('Date')
plt.ylabel('Volume')
# Out:
# Text(0, 0.5, 'Volume')

# %%
#43. Create a scatter plot of High vs. Low.

sns.scatterplot(x='High',y='Low',data=df)
# Out:
# <Axes: xlabel='High', ylabel='Low'>

# %%
#44. Plot the daily price difference (High- Low) over time.

plt.plot(df['Date'], df['Daily_Price'], label='Daily_Price', color='brown')
plt.title('Trading Daily_Price Over Time')
plt.xlabel('Date')
plt.ylabel('Daily_Price')
plt.grid()
plt.show()

# %%
#45. Visualize the total Volume traded each year using a bar chart.

plt.bar(df['Year'], df['Volume'], color='skyblue')

# Add labels and title
plt.title('Total Volume Traded Each Year')
plt.xlabel('Year')
plt.ylabel('Total Volume')
plt.show()
